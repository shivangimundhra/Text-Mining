# %%
import re

leg = open('/Users/shivangi/Documents/14216869.txt') # remember to change the filepath to the path on your computer
count = 0
for line in leg:
    line = line.rstrip() #remove the white spaces etc at the end of the line
    if re.search('negative', line):
        if re.search('1', line):
            count = count + 1
            print(re.findall('([a-zA-Z]+).',line)[0])
# Out:
# abandon
# abandoned
# abandonment
# abduction
# aberrant
# aberration
# abhor
# abhorrent
# abject
# abnormal
# abolish
# abolition
# abominable
# abomination
# abort
# abortion
# abortive
# abrasion
# abrogate
# abscess
# absence
# absent
# absentee
# absenteeism
# absurd
# absurdity
# abundance
# abuse
# abysmal
# abyss
# accident
# accidental
# accursed
# accusation
# accusative
# accused
# accuser
# accusing
# ache
# aching
# acid
# actionable
# adder
# addiction
# adipose
# adjudicate
# admonition
# adrift
# adulterated
# adultery
# adversary
# adverse
# adversity
# afflict
# afflicted
# affliction
# affront
# afraid
# aftermath
# aftertaste
# aggravated
# aggravating
# aggravation
# aggression
# aggressive
# aggressor
# aghast
# agitated
# agitation
# agonizing
# agony
# aground
# ail
# ailing
# aimless
# airs
# alarm
# alarming
# alcoholism
# alien
# alienate
# alienated
# alienation
# alimony
# allegation
# allege
# aloof
# altercation
# ambiguous
# ambush
# amnesia
# ...

# %%
count
# Out:
# 3325

# %% [markdown]
# As seen above, below code should be used to find all negative words in NRC emoticon lexicon.
#
# leg = open('/Users/shivangi/Documents/14216869.txt') # remember to change the filepath to the path on your computer
# count = 0
# for line in leg:
#     line = line.rstrip() #remove the white spaces etc at the end of the line
#     if re.search('negative', line):
#         count = count + 1
#         print(re.findall('([a-zA-Z]+).',line)[0])
# # print(count)
#
# Total number of negative words in NRC lexicon = 3325
#
# Total negative words are included in the LIWC 2007 lexicon = 57
#
# Some examples of negative words that are in NRC but not in LIWC =
#
# aback
# abacus
# abate
# abbot
# abbreviate
